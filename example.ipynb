# %% [markdown]
# # Sample Notebook
# This is a **test** notebook with `code` and outputs.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
2 + 2
# Out:
# 4

# %%
1 / 0
# Out:
# Traceback (most recent call last):
# ZeroDivisionError: division by zero
